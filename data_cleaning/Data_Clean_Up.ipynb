# %%
#Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import String

# %%
#Loading CSV files
data = "Resources/listings 2.csv"

# %%
#CSV to DataFrame
data_df = pd.read_csv(data, low_memory=False)
data_df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20200212052255   2020-02-12
# 1  5858  https://www.airbnb.com/rooms/5858  20200212052255   2020-02-12
# 2  7918  https://www.airbnb.com/rooms/7918  20200212052255   2020-02-12
# 3  8142  https://www.airbnb.com/rooms/8142  20200212052255   2020-02-12
# 4  8339  https://www.airbnb.com/rooms/8339  20200212052255   2020-02-12
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                              summary  \
# 0  New update: the house next door is under const...
# 1                                                NaN
# 2  Nice and good public transportation.  7 minute...
# 3  Nice and good public transportation.  7 minute...
# 4  Pls email before booking.  Interior featured i...
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  We live in a large Victorian house on a quiet ...
# 2  Settle down, S.F. resident, student, hospital,...
# 3  Settle down, S.F. resident, student, hospital,...
# 4  Please send us a quick message before booking ...
#
#                                          description experiences_offered  \
# 0  New update: the house next door is under const...                none
# 1  We live in a large Victorian house on a quiet ...                none
# 2  Nice and good public transportation.  7 minute...                none
# 3  Nice and good public transportation.  7 minute...                none
# 4  Pls email before booking.  Interior featured i...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  *Quiet cul de sac in friendly neighborhood *St...  ...                t
# 1  I love how our neighborhood feels quiet but is...  ...                f
# 2  Shopping old town, restaurants, McDonald, Whol...  ...                f
# 3                                                NaN  ...                f
# 4                                                NaN  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               9
# 3                               9
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            9
# 3                                            9
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.81
# 1                                            0               0.85
# 2                                            0               0.14
# 3                                            0               0.12
# 4                                            0               0.22
#
# [5 rows x 106 columns]

# %%
#getting columns' names for data set selection
data_df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
#Selecting colums for a new data frame
mapping_select = ["id", "name", "neighbourhood_cleansed","latitude","longitude","room_type","minimum_maximum_nights","license"]
#Making a copy of the new data set
mapping_data= data_df[mapping_select].copy()
mapping_data
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 2         7918         A Friendly Room - UCSF/USF - San Francisco
# 3         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4         8339                    Historic Alamo Square Victorian
# ...        ...                                                ...
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
# 8586  42225495  Private 2 bedrooms + bathroom + dedicated parking
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 2            Haight Ashbury  37.766690 -122.452500     Private room
# 3            Haight Ashbury  37.764870 -122.451830     Private room
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# ...                     ...        ...         ...              ...
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
# 8586           Outer Sunset  37.755530 -122.492718     Private room
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 2                         60          NaN
# 3                         90          NaN
# 4                        111  STR-0000264
# ...                      ...          ...
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
# 8586                    1125      1104215
#
# [8587 rows x 8 columns]

# %%
#Checking data types of each column
mapping_data.dtypes
# Out:
# id                          int64
# name                       object
# neighbourhood_cleansed     object
# latitude                  float64
# longitude                 float64
# room_type                  object
# minimum_maximum_nights      int64
# license                    object
# dtype: object

# %%
#Pulling and counting unique values in room_type column
mapping_data.room_type.value_counts()
# Out:
# Entire home/apt    5076
# Private room       3098
# Shared room         302
# Hotel room          111
# Name: room_type, dtype: int64

# %%
#Dropping dublicates in ID column
mapping_data.drop_duplicates("id", inplace=True)
#Dropping rows with "Hotel room" value in room_type, because we want to analyze privetly owned properties managed by a host
mapping_df = mapping_data[mapping_data.room_type != 'Hotel room']
mapping_df
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 2         7918         A Friendly Room - UCSF/USF - San Francisco
# 3         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4         8339                    Historic Alamo Square Victorian
# ...        ...                                                ...
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
# 8586  42225495  Private 2 bedrooms + bathroom + dedicated parking
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 2            Haight Ashbury  37.766690 -122.452500     Private room
# 3            Haight Ashbury  37.764870 -122.451830     Private room
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# ...                     ...        ...         ...              ...
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
# 8586           Outer Sunset  37.755530 -122.492718     Private room
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 2                         60          NaN
# 3                         90          NaN
# 4                        111  STR-0000264
# ...                      ...          ...
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
# 8586                    1125      1104215
#
# [8476 rows x 8 columns]

# %%
#Dropping rows with "License not needed per OSTR" value in license
mapping_df_2 = mapping_df[mapping_df.license != 'License not needed per OSTR']
mapping_df_2
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 2         7918         A Friendly Room - UCSF/USF - San Francisco
# 3         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4         8339                    Historic Alamo Square Victorian
# ...        ...                                                ...
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
# 8586  42225495  Private 2 bedrooms + bathroom + dedicated parking
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 2            Haight Ashbury  37.766690 -122.452500     Private room
# 3            Haight Ashbury  37.764870 -122.451830     Private room
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# ...                     ...        ...         ...              ...
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
# 8586           Outer Sunset  37.755530 -122.492718     Private room
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 2                         60          NaN
# 3                         90          NaN
# 4                        111  STR-0000264
# ...                      ...          ...
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
# 8586                    1125      1104215
#
# [8001 rows x 8 columns]

# %%
#Dropping rows with "Licensed Hotel/B&B" value in license
mapping_df_2 = mapping_df_2[mapping_df_2.license != 'Licensed Hotel/B&B']
mapping_df_2
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 2         7918         A Friendly Room - UCSF/USF - San Francisco
# 3         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4         8339                    Historic Alamo Square Victorian
# ...        ...                                                ...
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
# 8586  42225495  Private 2 bedrooms + bathroom + dedicated parking
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 2            Haight Ashbury  37.766690 -122.452500     Private room
# 3            Haight Ashbury  37.764870 -122.451830     Private room
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# ...                     ...        ...         ...              ...
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
# 8586           Outer Sunset  37.755530 -122.492718     Private room
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 2                         60          NaN
# 3                         90          NaN
# 4                        111  STR-0000264
# ...                      ...          ...
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
# 8586                    1125      1104215
#
# [7956 rows x 8 columns]

# %%
#Converting all lowercase characters in "license" column into uppercase characters for checking values to 
#determine legal/illigal status
mapping_df_2['license'].str.upper()
mapping_df_2
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 2         7918         A Friendly Room - UCSF/USF - San Francisco
# 3         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4         8339                    Historic Alamo Square Victorian
# ...        ...                                                ...
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
# 8586  42225495  Private 2 bedrooms + bathroom + dedicated parking
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 2            Haight Ashbury  37.766690 -122.452500     Private room
# 3            Haight Ashbury  37.764870 -122.451830     Private room
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# ...                     ...        ...         ...              ...
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
# 8586           Outer Sunset  37.755530 -122.492718     Private room
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 2                         60          NaN
# 3                         90          NaN
# 4                        111  STR-0000264
# ...                      ...          ...
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
# 8586                    1125      1104215
#
# [7956 rows x 8 columns]

# %%
#Filtering data set by  "Entire home/apt" value in "room_type" column
mapping_new = mapping_df_2.loc[mapping_df_2['room_type'] == "Entire home/apt"]
mapping_new
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 4         8339                    Historic Alamo Square Victorian
# 7        10251                   Victorian Suite in Inner Mission
# 8        10578                Classic Nob Hill Studio - Roof Deck
# ...        ...                                                ...
# 8580  42207965      Luxury 2 bedroom apartment in Pacific Heights
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# 7                   Mission  37.758740 -122.413270  Entire home/apt
# 8                  Nob Hill  37.791430 -122.415440  Entire home/apt
# ...                     ...        ...         ...              ...
# 8580       Western Addition  37.789142 -122.431616  Entire home/apt
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 4                        111  STR-0000264
# 7                         60  STR-0001558
# 8                        180          NaN
# ...                      ...          ...
# 8580                    1125          NaN
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
#
# [4861 rows x 8 columns]

# %%
#Adding "illigal" column to fill in after checking "for-loop" condotions in each row of the data
mapping_new['illegal'] = ''
mapping_new
# Out:
# C:\Users\melis\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 4         8339                    Historic Alamo Square Victorian
# 7        10251                   Victorian Suite in Inner Mission
# 8        10578                Classic Nob Hill Studio - Roof Deck
# ...        ...                                                ...
# 8580  42207965      Luxury 2 bedroom apartment in Pacific Heights
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# 7                   Mission  37.758740 -122.413270  Entire home/apt
# 8                  Nob Hill  37.791430 -122.415440  Entire home/apt
# ...                     ...        ...         ...              ...
# 8580       Western Addition  37.789142 -122.431616  Entire home/apt
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
#
#       minimum_maximum_nights      license illegal
# 0                         30  STR-0001256
# 1                         60          NaN
# 4                        111  STR-0000264
# 7                         60  STR-0001558
# 8                        180          NaN
# ...                      ...          ...     ...
# 8580                    1125          NaN
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
#
# [4861 rows x 9 columns]

# %%
#For-loop conditions which determine legal/illigal status of listed properties in San Francisco county
for i in range(len(mapping_new)) : 
    licence =  mapping_new.iloc[i,7] #assigning licence string into a variable
    #print(licence)
    #print(mapping_new.iloc[i,6])
    if isinstance(licence, float) == False:
        if (mapping_new.iloc[i,6] <= 90 and licence.startswith('STR')) :
            mapping_new.iloc[i,8]= 'legal'
            #add 'legal' to the illegal column if min-max rental nights equal or less then 90 night and property has license # starting with "STR"
        else:
            mapping_new.iloc[i,8]= 'illegal'
            #add 'illegal' to the legal column if min-max rental nights more then 90 or property has no license # starting with "STR"
    else: 
        mapping_new.iloc[i,8]= 'illegal'
# Out:
# C:\Users\melis\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
#checking Data Frame
mapping_new
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 4         8339                    Historic Alamo Square Victorian
# 7        10251                   Victorian Suite in Inner Mission
# 8        10578                Classic Nob Hill Studio - Roof Deck
# ...        ...                                                ...
# 8580  42207965      Luxury 2 bedroom apartment in Pacific Heights
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# 7                   Mission  37.758740 -122.413270  Entire home/apt
# 8                  Nob Hill  37.791430 -122.415440  Entire home/apt
# ...                     ...        ...         ...              ...
# 8580       Western Addition  37.789142 -122.431616  Entire home/apt
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
#
#       minimum_maximum_nights      license  illegal
# 0                         30  STR-0001256    legal
# 1                         60          NaN  illegal
# 4                        111  STR-0000264  illegal
# 7                         60  STR-0001558    legal
# 8                        180          NaN  illegal
# ...                      ...          ...      ...
# 8580                    1125          NaN  illegal
# 8582                    1125          NaN  illegal
# 8583                    1125          NaN  illegal
# 8584                     365          NaN  illegal
# 8585                     365          NaN  illegal
#
# [4861 rows x 9 columns]

# %%
#Creating output csv file 
#This csv file will be uploaded to a sqlite database via DB Browser
mapping_new.to_csv("Output/mapping_data.csv", index = False)

# %%
#Saving priviously created data frame to new variable 
roomtype_df = mapping_df_2
roomtype_df
# Out:
#             id                                               name  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B
# 1         5858                                 Creative Sanctuary
# 2         7918         A Friendly Room - UCSF/USF - San Francisco
# 3         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4         8339                    Historic Alamo Square Victorian
# ...        ...                                                ...
# 8582  42220964  Roomy Nob Hill Studio w/ W/D, nr. SFMH & Trade...
# 8583  42220998  Spacious Castro 2BR w/ W/D in the building, nr...
# 8584  42221541   Sonder | Duboce Apartments | Desirable 2BR + Gym
# 8585  42221876  Sonder | Duboce Apartments | Dashing 1BR + Roo...
# 8586  42225495  Private 2 bedrooms + bathroom + dedicated parking
#
#      neighbourhood_cleansed   latitude   longitude        room_type  \
# 0          Western Addition  37.769310 -122.433860  Entire home/apt
# 1            Bernal Heights  37.745110 -122.421020  Entire home/apt
# 2            Haight Ashbury  37.766690 -122.452500     Private room
# 3            Haight Ashbury  37.764870 -122.451830     Private room
# 4          Western Addition  37.775250 -122.436370  Entire home/apt
# ...                     ...        ...         ...              ...
# 8582  Downtown/Civic Center  37.788591 -122.418200  Entire home/apt
# 8583    Castro/Upper Market  37.762246 -122.440132  Entire home/apt
# 8584    Castro/Upper Market  37.767051 -122.429778  Entire home/apt
# 8585    Castro/Upper Market  37.766826 -122.429836  Entire home/apt
# 8586           Outer Sunset  37.755530 -122.492718     Private room
#
#       minimum_maximum_nights      license
# 0                         30  STR-0001256
# 1                         60          NaN
# 2                         60          NaN
# 3                         90          NaN
# 4                        111  STR-0000264
# ...                      ...          ...
# 8582                    1125          NaN
# 8583                    1125          NaN
# 8584                     365          NaN
# 8585                     365          NaN
# 8586                    1125      1104215
#
# [7956 rows x 8 columns]

# %%
#Making a copy of a data set
room_type_df= mapping_df_2.copy()
#Grouping data by "room_type" and counting values
roomtype_new = room_type_df.groupby('room_type')['id'].count()
roomtype_new
# Out:
# room_type
# Entire home/apt    4861
# Private room       2822
# Shared room         273
# Name: id, dtype: int64

# %%
#Creating new data frame using groupby results
room_type_df = pd.DataFrame(roomtype_new)
#Renaming column "id" to "count"
room_type_df = room_type_df.rename(columns={ "id": "count"})
#room_type_df = room_type_df.reset_index()
room_type_df
# Out:
#                  count
# room_type
# Entire home/apt   4861
# Private room      2822
# Shared room        273

# %%
#Calculating sum of all room types to use for percentage calculation
total_count = sum(room_type_df["count"])
#Creating variable to hold percentage data and calculating percentage 
prcnt = (room_type_df["count"])/total_count*100

# %%
#Adding "percentage" column to Data Ftame in % format
room_type_df['percentage'] = prcnt.map('{:,.2f}%'.format)
room_type_df
# Out:
#                  count percentage
# room_type
# Entire home/apt   4861     61.10%
# Private room      2822     35.47%
# Shared room        273      3.43%

# %%
##This csv file will be uploaded to a sqlite database via DB Browser
room_type_df.to_csv("Output/grouped_roomtype.csv")

# %%
#Making a copy of a data set
legal_df= mapping_new.copy()
#Grouping data by legal/illigal status and counting values
legal_df = legal_df.groupby('illegal')['id'].count()
legal_df
# Out:
# illegal
# illegal    3836
# legal      1025
# Name: id, dtype: int64

# %%
#Creating new data frame using groupby results
leg_illeg_df = pd.DataFrame(legal_df)
#Renaming column "id" to "count"
leg_illeg_df = leg_illeg_df.rename(columns={ "id": "count"})
leg_illeg_df
# Out:
#          count
# illegal
# illegal   3836
# legal     1025

# %%
#Calculating sum of all properties to use for percentage calculation
total_count_2 = sum(leg_illeg_df["count"])
#Creating variable to hold percentage data and calculating percentage 
prcnt_2 = (leg_illeg_df["count"])/total_count_2*100

# %%
#Adding "percentage" column to Data Ftame in % format
leg_illeg_df['percentage'] = prcnt_2.map('{:,.2f}%'.format)
leg_illeg_df
# Out:
#          count percentage
# illegal
# illegal   3836     78.91%
# legal     1025     21.09%

# %%
##This csv file will be uploaded to a sqlite database via DB Browser
leg_illeg_df.to_csv("Output/legal.csv")

# %%
#Making a copy of a data set
nh= mapping_df.copy()
#Grouping values by "neighbourhood_cleansed" and "room_type" and counting properties by room type
nh = nh.groupby(["neighbourhood_cleansed","room_type"])["room_type"].count()
#Converting groupby results into Data Frame
nh_df = pd.DataFrame(nh)
#Renaming column "room_type" to "count"
nh_df = nh_df.rename(columns={ "room_type": "count"})
nh_df
# Out:
#                                         count
# neighbourhood_cleansed room_type
# Bayview                Entire home/apt     82
#                        Private room       137
#                        Shared room          2
# Bernal Heights         Entire home/apt    266
#                        Private room       137
# ...                                       ...
# West of Twin Peaks     Entire home/apt     73
#                        Private room        70
# Western Addition       Entire home/apt    385
#                        Private room       211
#                        Shared room         27
#
# [96 rows x 1 columns]

# %%
#Using pivot function to restructure Data Frame
table = pd.pivot_table(nh_df, values='count',
                    columns="room_type", index= "neighbourhood_cleansed")
#Changing NaN value to 0
table= table.fillna(0)
#Changing floats to int 
table["Entire home/apt"] = table["Entire home/apt"].astype(int)
table["Shared room"] = table["Shared room"].astype(int)
table["Private room"] = table["Private room"].astype(int)
#Renaming columns
table = table.rename(columns={ "Entire home/apt": "entire_house",
                               "Private room": "private_room",
                               "Shared room": "shared_room"
                             })
#sum_ent=(table["Entire home/apt"]).sum()
#sum_pr=(table["Private room"]).sum()
#sum_sh=(table["Shared room"]).sum()
#sum_ttl = sum_ent+sum_pr+sum_sh
#entire_house, private_room, shared_room
table
# Out:
# room_type               entire_house  private_room  shared_room
# neighbourhood_cleansed
# Bayview                           82           137            2
# Bernal Heights                   266           137            1
# Castro/Upper Market              305           151            2
# Chinatown                        103            42            9
# Crocker Amazon                    34            29            1
# Diamond Heights                    8             8            0
# Downtown/Civic Center            343           336           31
# Excelsior                         77           103            1
# Financial District               152            53           15
# Glen Park                         50            15            0
# Golden Gate Park                   4             1            0
# Haight Ashbury                   228           125           52
# Inner Richmond                   132            83           25
# Inner Sunset                     112            54            1
# Lakeshore                         22            39            1
# Marina                           150            49            0
# Mission                          463           293           22
# Nob Hill                         184           134           16
# Noe Valley                       224            99            1
# North Beach                      109            73           37
# Ocean View                        57            69            8
# Outer Mission                     81            90            4
# Outer Richmond                   113            71            0
# Outer Sunset                     160           160            6
# Pacific Heights                  124            44            0
# Parkside                          81            58            6
# Potrero Hill                     163            83            1
# Presidio                           0             1            0
# Presidio Heights                  23             3            0
# Russian Hill                     144            47            4
# Seacliff                          15            10            0
# South of Market                  512           161           29
# Treasure Island/YBI                1             0            0
# Twin Peaks                        50            24            0
# Visitacion Valley                 46            35            0
# West of Twin Peaks                73            70            0
# Western Addition                 385           211           27

# %%
##This csv file will be uploaded to a sqlite database via DB Browser
table.to_csv("Output/grouped_neighborhoods.csv")
